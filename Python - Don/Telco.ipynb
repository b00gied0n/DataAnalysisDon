# %%
import pandas as pd
import numpy as np

df = pd.read_excel(r'C:\Users\Don.Rombaoa\Downloads\Python - Don\Telco\8.7 Logistic Regression - Telco Customer Churn - Training Dataset.xlsx', sheet_name='Telco Customer Churn')
df
# Out:
#       CustomerID  Gender Partner Dependents  Tenure        Contract  \
# 0     0280-XJGEX    Male      No         No      49  Month-to-month
# 1     6865-JZNKO  Female      No         No      30  Month-to-month
# 2     7310-EGVHZ    Male      No         No       1  Month-to-month
# 3     3413-BMNZE    Male      No         No       1  Month-to-month
# 4     8168-UQWWF  Female      No         No      11  Month-to-month
# ...          ...     ...     ...        ...     ...             ...
# 3061  4616-ULAOA  Female     Yes        Yes      65        Two year
# 3062  2314-TNDJQ  Female     Yes        Yes      72        Two year
# 3063  3454-JFUBC    Male      No         No      68        Two year
# 3064  9588-YRFHY    Male      No         No      49        Two year
# 3065  5130-YPIRV  Female     Yes         No      62        Two year
#
#      PaymentMethod  MonthlyCharges TotalCharges Churn
# 0     Direct debit          103.70       5036.3   Yes
# ...
