# %% [markdown]
# ## Titanic - Python Exercises

# %% [markdown]
# ## Step 1: Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

df = pd.read_excel(r'C:\Users\Don.Rombaoa\Downloads\Python - Don\Titanic\Titanic Train.xlsx')
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %% [markdown]
# ## Step 2: Data Quality
#
# 1. Head/Tail - Columns makes sense, data represents what column is saying and missing values check
# 2. Dimensions (size of dataset - count of columns and rows)
# 3. Info - Get data types, data structure, column list, and nulls-completion rate
# 4. Summary Stats - Conduct descriptive stats for each column
# 4. Granularity - What level of granularity is the rows (Whats the uniqueid representing? e.g. city, customer, or transaction?)
# 5. Nulls - missing values count across all columns
# 6. Distinct Values - how many distinct values per column (look for blanks! or notations that indicate incorrect/missing data)
# 7. Duplicates - how many and how prevaluent (%) of duplicates in your data
# 8. Time Range - check the date range of the data
# 9. Measure of Interest - Does it have your money-associated KPI (e.g. revenue, profits, sales, conversion rate, reach, etc)
# 9. Data gaps - check whether the data covers all months, year combination - looking for sudden drops or spikes in the KPI

# %%
# Check Head 
df.head(10)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                             Mr. Owen Harris Braund    male  22.0
# 1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2       3                              Miss. Laina Heikkinen  female  26.0
# 3       1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4       3                            Mr. William Henry Allen    male  35.0
# 5       3                                    Mr. James Moran    male  27.0
# 6       1                             Mr. Timothy J McCarthy    male  54.0
# 7       3                      Master. Gosta Leonard Palsson    male   2.0
# 8       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson  female  27.0
# 9       2                 Mrs. Nicholas (Adele Achem) Nasser  female  14.0
#
#    Siblings/Spouses Aboard  Parents/Children Aboard     Fare  Survived
# 0                        1                        0   7.2500         0
# ...

# %%
# Check Tail 
df.tail(10)
# Out:
#      Pclass                                 Name     Sex   Age  \
# 877       3                    Mr. Johann Markun    male  33.0
# 878       3          Miss. Gerda Ulrika Dahlberg  female  22.0
# 879       2         Mr. Frederick James Banfield    male  28.0
# 880       3                Mr. Henry Jr Sutehall    male  25.0
# 881       3  Mrs. William (Margaret Norton) Rice  female  39.0
# 882       2                 Rev. Juozas Montvila    male  27.0
# 883       1          Miss. Margaret Edith Graham  female  19.0
# 884       3       Miss. Catherine Helen Johnston  female   7.0
# 885       1                 Mr. Karl Howell Behr    male  26.0
# 886       3                   Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare  Survived
# 877                        0                        0   7.8958         0
# 878                        0                        0  10.5167         0
# ...

# %%
# Check Dimensions
df.shape
# Out:
# (887, 8)

# %%
# Columns + Data Types + Null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Pclass                   887 non-null    int64
#  1   Name                     887 non-null    object
#  2   Sex                      887 non-null    object
#  3   Age                      887 non-null    float64
#  4   Siblings/Spouses Aboard  887 non-null    int64
#  5   Parents/Children Aboard  887 non-null    int64
#  6   Fare                     887 non-null    float64
#  7   Survived                 887 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
# Nulls Count
df.isnull().sum()
# Out:
# Pclass                     0
# Name                       0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# Survived                   0
# dtype: int64

# %%
# Not Nulls Count
df.notnull().sum()
# Out:
# Pclass                     887
# Name                       887
# Sex                        887
# Age                        887
# Siblings/Spouses Aboard    887
# Parents/Children Aboard    887
# Fare                       887
# Survived                   887
# dtype: int64

# %%
# Unique Values


# Unique Values
print(df.Sex.unique())

# Count of Unique Values
print(df.Sex.value_counts())

# Count Unique Values for ALL Columns - Include Nulls
print(df.nunique(dropna=False))

# Count Unique Values for ALL Columns - No Nulls
print(df.nunique(dropna=True))
# Out:
# ['male' 'female']
# male      573
# female    314
# Name: Sex, dtype: int64
# Pclass                       3
# Name                       887
# Sex                          2
# Age                         89
# Siblings/Spouses Aboard      7
# Parents/Children Aboard      7
# Fare                       248
# Survived                     2
# dtype: int64
# Pclass                       3
# Name                       887
# Sex                          2
# Age                         89
# Siblings/Spouses Aboard      7
# Parents/Children Aboard      7
# Fare                       248
# Survived                     2
# dtype: int64

# %%
# SUMMARY STATISTICS (DESCRIPTIVE STATS)


#Just Numerical Data
df.describe()


# All Data Incl/ Categorical Data (Same as R)
df.describe(include='all')
# Out:
#             Pclass                  Name   Sex         Age  \
# count   887.000000                   887   887  887.000000
# unique         NaN                   887     2         NaN
# top            NaN  Mr. Charles Wilhelms  male         NaN
# freq           NaN                     1   573         NaN
# mean      2.305524                   NaN   NaN   29.471443
# std       0.836662                   NaN   NaN   14.121908
# min       1.000000                   NaN   NaN    0.420000
# 25%       2.000000                   NaN   NaN   20.250000
# 50%       3.000000                   NaN   NaN   28.000000
# 75%       3.000000                   NaN   NaN   38.000000
# max       3.000000                   NaN   NaN   80.000000
#
#         Siblings/Spouses Aboard  Parents/Children Aboard       Fare  \
# count                887.000000               887.000000  887.00000
# unique                      NaN                      NaN        NaN
# ...

# %%
# Count + Percentages

# Step 1: Extract target column
#s = df.Sex
#print(df.Sex.value_counts())

# Step 2: Get distribution
#counts = s.value_counts()
#print(counts)

# Step 3: Get percentages (decimals)
#percent = s.value_counts(normalize=True)
#print(percent)

# Step 4: Convert to % (must convert to ABC to add % symbol)
#percent100 = s.value_counts(normalize=True).mul(100).round(4).astype(str) + '%'
#print(percent100)

# Step 5: Combine all the stats
#pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#         counts       per    per100
# male       573  0.645998  64.5998%
# female     314  0.354002  35.4002%

# %% [markdown]
# ## Data Wrangling
#
# 0. Index - Create + Remove
# 1. Fill Values - Null + Empty + NA + Missing Data
# 2. Add/Remove Columns (e.g. Calculated Columns)
# 3. Conditions (IF) - Binary (e.g. Survived / Not Survived) + Bins (e.g. Age Groups)
# 4. Dummies - Distribution (All Dummies) + Supervised (Drop First)
# 5. Convert Datatype
# 6. Extract (e.g Month from Date, Word, Delimeters)
# 7. Text to Columns
# 8. Filter
# 9. Manipulate Rows (e.g. Order + Move + Delete)
# 10. Indexing Measures (Normalise)
# 11. Binning - Width / Frequency
# 12. Blending
# 13. Remove Duplicates
# 14. Change Values

# %%
# Blending

# Use Male Flag from another excel sheet to update the titanic table.

# 1. load male excel sheet
df_male = pd.read_excel(r'C:\Users\Don.Rombaoa\Downloads\Python - Don\Titanic\Titanic - Flag Male.xlsx')


#2 Left Join male excel sheet
df2 = df.merge(df_male, on='Sex', how='left')


#3 Counts 
df2.Flag_Male.value_counts()


#4 Put in a table 
grouped_df = df2.groupby(["Flag_Male"])

#pd.DataFrame(grouped_df.size().reset_index(name = "Group_Count"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c0adc7e05247> in <module>
#       6
#       7 #3 Counts
# ----> 8 df2.Flag_Male.value_counts()
#       9
#      10
#
# NameError: name 'df2' is not defined

# %% [raw]
# # MERGE #2
# # Step 1 - Load titanic full dataset
# df = pd.read_excel(r'C:\Users\Don.Rombaoa\Downloads\Python - Don\Titanic\Titanic Train.xlsx')
#
# # Step 2 - load MALE ONLY titanic dataset
# df_male = pd.read_excel(r'C:\Users\Don.Rombaoa\Downloads\Python - Don\Titanic\Titanic - Flag Male.xlsx')
#
# # Step 3 - Left Join the male excel sheet to the original DF ()
# df2 = df.merge(df_male, on='Sex', how='left')

# %%
#DUPLICATES - IDENTIFY

# STEP 1: sorting by age and first name
df2.sort_values(["Age", "Name"], inplace = True)
df2  

# STEP 2: making a bool series
bool_series = df2["Name"].duplicated(keep = False)
  
# bool series
bool_series
  
# STEP 3: passing NOT of bool series to see unique values only

#UNIQUE VALUES
#data = data[~bool_series]

#DUPLICATES
#df3 = df2[bool_series]

# displaying data
#df3.info()
#df3
# Out:
# 799    False
# 751    False
# 641    False
# 466    False
# 77     False
#        ...
# 115    False
# 95     False
# 490    False
# 847    False
# 627    False
# Name: Name, Length: 887, dtype: bool

# %%
#Duplicates - Remove

df.drop_duplicates()
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %%
#Indexing

# Create new column with ROW INDEX START AT 0
#df2.insert(loc=0, column='ID', value=np.arange(0,len(df2)))

# Create new column with ROW INDEX START AT 1
#df2.insert(loc=0, column='ID2', value=np.arange(1,len(df2)+1))

#Set Index for a SPECIFIED COLUMN
df2.set_index(['ID'], inplace=True)

# %%
# Binning/Encoding

df2['AgeGroup'] = df2['Age'].apply(
    lambda x : '66+'  if (x > 65) else (
               '56-65' if (x > 55) else (
               '46-55' if (x > 45) else (
               '36-45' if (x > 35) else (
               '26-35' if (x > 25) else (
               '16-25' if (x > 15) else (
               '00-15' if (x >= 0) else 'unknown')))))))


# Add New Columns - Conditional (Binary) - LAMBDA
df2['Flag_Fare_Expensive'] = df2['Fare'].apply(
    lambda x : 'Yes'  if (x >= 100) else 'No')


# Add New Columns - Conditional (Binary) - NUMPY (Easiest)
df2['Flag_Fare_Expensive2'] = np.where(df2['Fare']>=100, 1, 0)

df2
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %%
# ADD/COPY COLUMNS 

# Add Empty Column
#df2["ID"] = np.nan


# Copy Columns 
#df2['Sex1'] = df2['Sex']


# Drop a Column
#df2 = df2.drop(['ID'], axis=1)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %%
# REMOVE ROWS with Missing Data

df2=df2.dropna(subset = ['Age'])

# %%
# Change Values

# via Numpy (Binary Only with alternatives)
df2['Sex1'] = np.where((df2.Sex == 'male'), 'm', 'f')

# via .loc (Binary but specific only)
df2.loc[(df2.Sex == 'female'), 'Sex2'] = 'Female'
df2.loc[(df2.Sex == 'male'), 'Sex2'] = 'Male'

df2
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %%
# Extraction 

# Extract Year
#df['year'] = pd.DatetimeIndex(df['Date Attribute']).year

# Extract Month
#df['month'] = pd.DatetimeIndex(df['Date Attribute']).month
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %%
#FILTER - REGEX

df2[df2['Name'].str.match('^Mrs.*')== True]

#EXTRACTION - ALL but THE SPECIFIC WORDS (REGEX)
df2[df2['Name'].str.match('^Mrs.*')== False]


# Specific Columns with Conditions from Other Columns
df2_FareClass1 = df2[df2.Fare>50][["Fare","Pclass"]]
# Out:
#      Pclass                            Name     Sex   Age  \
# 0         3          Mr. Owen Harris Braund    male  22.0
# 2         3           Miss. Laina Heikkinen  female  26.0
# 4         3         Mr. William Henry Allen    male  35.0
# 5         3                 Mr. James Moran    male  27.0
# 6         1          Mr. Timothy J McCarthy    male  54.0
# ..      ...                             ...     ...   ...
# 882       2            Rev. Juozas Montvila    male  27.0
# 883       1     Miss. Margaret Edith Graham  female  19.0
# 884       3  Miss. Catherine Helen Johnston  female   7.0
# 885       1            Mr. Karl Howell Behr    male  26.0
# 886       3              Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare  Survived  \
# 0                          1                        0   7.2500         0
# 2                          0                        0   7.9250         1
# ...

# %%
# Interpolation - Fill NA

# STEP 1: Make Empty Column
df2["Empty_1"] = np.nan


# Drop Empty Column
#df2=df2.drop(['Empty_2'], axis=1)

# STEP 2: Fill NA with Unknown - FULL EMPTY COLUMN
df2['Empty_1']=df2.Empty_1.fillna(value = 'Unknown')


#STEP 3: FIll with Binary labels
df2['Empty_1'] = np.where((df2.Survived == 1), 'Alive', 'Dead')
df2




# Fill NA - Specific Empty Rows
#DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)
#df2["Empty_2"].fillna("Try Again", inplace = True)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %%
# EXERCEISE: 1. FIND SPECIFIC CELLS AND 2.CONVERT TO NULLS AND 3.FILL AGAIN WITH BACKFILL

#FILTER - SPECIFIC COLUMNS AND ROWS [rows, [columns]
# df.loc[ 0:100 , ['column1', 'column2']
df2.loc[0:10,['Name','Age', 'Sex']]


# STEP 1: SPECIFIC CELL
df2.loc[[10],['Age']]


# SPECIFIC CELLS
#df2.loc[[0,10,20],['Age']]


# STEP 2: MAKE INTO NULLS - SPECIFIC CELL
df2.loc[[10],['Age']] = np.nan


# STEP 3: FILL NA - BACKFILL
df2.fillna(method ='bfill', inplace=True)


# STEP 4: CHECK DATA IS NOT NULL ANYMORE
df2.loc[[10],['Age']] # SPECIFIC CELL
df2.head(20) # ALL SURROUNDING CELLS

# %%
# Out:
#     Pclass                                               Name     Sex   Age  \
# 0        3                             Mr. Owen Harris Braund    male  22.0
# 1        1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2        3                              Miss. Laina Heikkinen  female  26.0
# 3        1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4        3                            Mr. William Henry Allen    male  35.0
# 5        3                                    Mr. James Moran    male  27.0
# 6        1                             Mr. Timothy J McCarthy    male  54.0
# 7        3                      Master. Gosta Leonard Palsson    male   2.0
# 8        3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson  female  27.0
# 9        2                 Mrs. Nicholas (Adele Achem) Nasser  female  14.0
# 10       3                     Miss. Marguerite Rut Sandstrom  female  58.0
# ...

# %%
# RENAME COLUMN

df2.rename(columns={"Empty_1":"Flag_Alive"})
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                             Mr. Owen Harris Braund    male  22.0
# 1         1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2         3                              Miss. Laina Heikkinen  female  26.0
# 3         1        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4         3                            Mr. William Henry Allen    male  35.0
# ..      ...                                                ...     ...   ...
# 882       2                               Rev. Juozas Montvila    male  27.0
# 883       1                        Miss. Margaret Edith Graham  female  19.0
# 884       3                     Miss. Catherine Helen Johnston  female   7.0
# 885       1                               Mr. Karl Howell Behr    male  26.0
# 886       3                                 Mr. Patrick Dooley    male  32.0
#
# ...

# %%
# Convert Datatypes

df["Age"] = df.Age.astype("float64")
df["Fare"] = df.Fare.astype("float64")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Pclass                   887 non-null    int64
#  1   Name                     887 non-null    object
#  2   Sex                      887 non-null    object
#  3   Age                      887 non-null    float64
#  4   Siblings/Spouses Aboard  887 non-null    int64
#  5   Parents/Children Aboard  887 non-null    int64
#  6   Fare                     887 non-null    float64
#  7   Survived                 887 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB
# None

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# 1. Descriptive Statistics - Central Tendency + Spread on Combos of Variables (e.g. Sex-AgeGroup avg Sales)
# 2. Distributions - Group By
# 3. Correlations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Pclass                   887 non-null    int64
#  1   Name                     887 non-null    object
#  2   Sex                      887 non-null    object
#  3   Age                      887 non-null    float64
#  4   Siblings/Spouses Aboard  887 non-null    int64
#  5   Parents/Children Aboard  887 non-null    int64
#  6   Fare                     887 non-null    float64
#  7   Survived                 887 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
# SURVIVAL RATE (COUNTS) 
df.groupby('Sex')[['Survived']].count()
# Out:
#         Survived
# Sex
# female       314
# male         573

# %%
# SURVIVAL RATE (PERCENTAGES QUICKLY - USE MEAN FOR CATEGORICAL VARIABLES)
df.groupby('Sex')[['Survived']].mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.190227

# %%
# GROUP BY - SUMMARY STATS OF PCLASS
df.groupby("Pclass").agg({"Fare": ['mean', 'min', 'max', 'count']})
# Out:
#              Fare
#              mean  min       max count
# Pclass
# 1       84.154687  0.0  512.3292   216
# 2       20.662183  0.0   73.5000   184
# 3       13.707707  0.0   69.5500   487

# %%
# PIVOT_TABLE - SURVIVAL RATE % BY SEX AND CLASS
df.pivot_table('Survived', index='Sex', columns='Pclass')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.137026

# %%
# DISTRIBUTIONS - QUICK WAY (FOR LOOP)

for column in df:
    print(df[column].value_counts())
    print()
# Out:
# 3    487
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#
# Mr. Walter Chamberlain Porter                1
# Mrs. Wilhelm (Elna Matilda Persson) Strom    1
# Mr. Charles Frederick Waddington Sedgwick    1
# Mr. Jacob Christian Milling                  1
# Mr. Henry Blank                              1
#                                             ..
# Mr. Yousseff Ibrahim Shawah                  1
# Mr. Rene Aime Lievens                        1
# Mlle. Emma Sagesser                          1
# Miss. Helmina Josefina Nilsson               1
# Mr. Nils Martin Odahl                        1
# Name: Name, Length: 887, dtype: int64
#
# male      573
# female    314
# Name: Sex, dtype: int64
#
# 22.00    39
# 28.00    37
# 18.00    36
# 21.00    34
# 24.00    34
#          ..
# 70.50     1
# 36.50     1
# 23.50     1
# 55.50     1
# 0.42      1
# Name: Age, Length: 89, dtype: int64
#
# 0    604
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# ...

# %%
# CORRELATIONS 
df.iloc[:,:].T.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Visualisations
#
#
# BI Analyst Visualisations
#
# 1. Bar Chart - Vertical, Horizontal, Stacked, Shares, Double Axis, Cumulative, Grid
# 2. Pie Chart - Pie + Donut Chart, Blown Up, Slice Distribution
# 3. Line Chart - Fixed Lines, Avg Line, Confidence Interval, Forecasting, Double Axis, Subplots
#
#
#
# Data Scientist Visualisations
#
# 4. Boxplot
# 5. Histogram
# 6. Scatter (e.g. Pairs)
# 7. Violin
# 8. Heatmap
#
#
# Geo
#
# 9. Bubble
# 10. Chloropleth
#
#
# Text Analytics
#
# 11. WordCloud

# %%
# Bar Chart

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# COUNT
sns.countplot(x='Survived', data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
# BoxPlot (via Matplotlib)
import matplotlib.pyplot as plt
import seaborn as sns

# Single Column
plt.boxplot(df['Age'], showmeans=True)
print(plt.show())


# Multi-Columns
plt.boxplot(df[['Age', 'Fare']], showmeans=True)
print(plt.show())



# boxplot of fare
plt.boxplot(df['Fare'], showmeans=True)
print(plt.show())
# Out:
# None

# %%
# Out:
# None
# None

# %%
## Histogram


# Automated - All Columns
for i in df.columns:
    plt.hist(df[i])
    plt.title(i)
    
    plt.show()

# %%
# GRAPH COLUMNS BY SURVIVAL RATE

cols = ['Sex', 'Pclass', 'Siblings/Spouses Aboard', 'Parents/Children Aboard']

n_rows = 2
n_cols = 2

# The subplot grid and the figure size of each graph
# This returns a Figure (fig) and an Axes Object (axs)
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols*5.0,n_rows*5.0))

for r in range(0,n_rows):
    for c in range(0,n_cols):  
        
        i = r*n_cols+ c #index to go through the number of columns       
        ax = axs[r][c] #Show where to position each subplot
        sns.countplot(df[cols[i]], hue=df["Survived"], ax=ax)
        ax.set_title(cols[i])
        ax.legend(title="Survived", loc='upper right') 
        
plt.tight_layout()   #tight_layout
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# PIVOT_TABLE - SURVIVAL RATE % BY SEX AND CLASS
df.pivot_table('Survived', index='Sex', columns='Pclass').plot()
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
# SURVIVAL BY CLASS (COUNTS)
sns.barplot(x='Pclass', y='Survived', data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ## MODEL BUILD
#
#
# 1. FEATURE ENGINEERING - PRE-PROCESSING DATA
# 2.

# %%
# !pip install dataprep

from dataprep.datasets import load_dataset
from dataprep.eda import create_report
# Out:
# ...
#   Using cached dataprep-0.3.0-py3-none-any.whl (1.8 MB)
# ...
#   Using cached wordcloud-1.8.1-cp38-cp38-win_amd64.whl (155 kB)
# ...
#   Using cached python-Levenshtein-0.12.2.tar.gz (50 kB)
# ...
#   Using cached aiohttp-3.7.4.post0-cp38-cp38-win_amd64.whl (635 kB)
# ...
#   Using cached yarl-1.6.3-cp38-cp38-win_amd64.whl (125 kB)
# ...
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# ...
#   Using cached multidict-5.1.0-cp38-cp38-win_amd64.whl (48 kB)
# ...
#   Running setup.py clean for python-Levenshtein
# Failed to build python-Levenshtein
# ...
#     Running setup.py install for python-Levenshtein: started
#     Running setup.py install for python-Levenshtein: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
# ...

# %%
from dataprep.datasets import load_dataset
from dataprep.eda import create_report
#df = load_dataset("titanic")
create_report(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-777ab02c3752> in <module>
# ----> 1 from dataprep.datasets import load_dataset
#       2 from dataprep.eda import create_report
#       3 #df = load_dataset("titanic")
#       4 create_report(df)
#
# ModuleNotFoundError: No module named 'dataprep'
